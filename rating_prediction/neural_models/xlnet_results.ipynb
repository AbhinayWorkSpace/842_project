# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

file_path = '/content/drive/MyDrive/xlnet_binary.pkl'

with open(file_path, 'rb') as f:
    xlnet_bin = pickle.load(f)

xlnet_bin
# Out:
# {'evaluation': [0.6931461691856384, 0.5055509805679321],
#  'history': {'loss': [0.6953611969947815], 'accuracy': [0.49858370423316956]}}

# %%
file_path = '/content/drive/MyDrive/xlnet_tri.pkl'

with open(file_path, 'rb') as f:
    xlnet_tri = pickle.load(f)

xlnet_tri
# Out:
# {'evaluation': [1.0986310243606567, 0.3328132629394531],
#  'history': {'loss': [1.1125199794769287], 'accuracy': [0.33369165658950806]}}

# %%
file_path = '/content/drive/MyDrive/xlnet_all.pkl'

with open(file_path, 'rb') as f:
    xlnet_all = pickle.load(f)

xlnet_all
# Out:
# {'evaluation': [1.6093803644180298, 0.20207543671131134],
#  'history': {'loss': [1.6099251508712769], 'accuracy': [0.19999772310256958]}}
