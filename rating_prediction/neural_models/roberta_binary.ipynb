# %%
from google.colab import drive

drive.mount('/content/drive')

file_path1 = '/content/drive/My Drive/beauty_personal_care.json'
file_path2 = '/content/drive/My Drive/beauty_personal_care.json'
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd

with open(file_path1, 'r') as file:
    data = [json.loads(line) for line in file]

with open(file_path2, 'r') as file:
    for line in file:
      data.append(json.loads(line))

df = pd.DataFrame(data)
df
# Out:
#          rating                                              title  \
# 0           1.0            Gasoline!! Seriously reeks of gasoline!
# 1           1.0  Useless!  These have massive gaps at pump nozzle.
# 2           5.0                             Hailey loves unicorns!
# 3           1.0                  Not sharp enough to cut smoothly.
# 4           3.0                Pretty, but didn’t close correctly.
# ...         ...                                                ...
# 1999995     5.0                          The only thing I can use!
# 1999996     5.0         Comfortable, good quality, enough to share
# 1999997     5.0                            Best product I’ve found
# 1999998     5.0                        Love Mario Badescu products
# 1999999     5.0                                        Pretty hair
#
#                                                       text  \
# 0        Opened the package & instant migraine. I canno...
# 1        Tops the list for worst purchase. Tried these ...
# 2        Bought this for my granddaughter.  Her entire ...
# 3        These are extremely dull and will wreck your n...
# 4        Mine wouldn’t close correctly so I sent it bac...
# ...                                                    ...
# 1999995  I love this product. It is the only thing I ha...
# 1999996  Great for home pedicures made necessary by Cov...
# 1999997  Love this product. It’s the only hand cream I’...
# 1999998  This is my favorite body wash product.  It doe...
# 1999999  Tried this instead of the same old product I'v...
#
#                                                     images        asin  \
# 0        [{'small_image_url': 'https://images-na.ssl-im...  B00Z03RC80
# 1        [{'small_image_url': 'https://images-na.ssl-im...  B085PRT2MP
# 2                                                       []  B08G81QQ9L
# 3                                                       []  B07YYG76X1
# 4                                                       []  B0761M33BX
# ...                                                    ...         ...
# 1999995                                                 []  B001E96ORO
# 1999996                                                 []  B008E0DBYA
# 1999997                                                 []  B07JL6KGBV
# 1999998                                                 []  B00172F9HO
# 1999999                                                 []  B006OHM5T2
#
#         parent_asin                       user_id      timestamp  \
# 0        B00Z03RC80  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1616743454733
# 1        B085PRT2MP  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1614915977684
# 2        B08G81QQ9L  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1612052493701
# 3        B07YYG76X1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1609700981786
# 4        B07X4FKLNK  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1581313195358
# ...             ...                           ...            ...
# 1999995  B001E96ORO  AEWBUDXP52UZXVWPS5NS7LU4LLPQ  1533327956534
# 1999996  B008E0DBYA  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1594660544449
# 1999997  B07JL6KGBV  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1588879094484
# 1999998  B0BZ1FYHS2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1576425314960
# 1999999  B006OHM5T2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1484085442000
#
#          helpful_vote  verified_purchase
# 0                   0               True
# 1                   0               True
# 2                   0               True
# 3                   0               True
# 4                   0               True
# ...               ...                ...
# 1999995             0               True
# 1999996             0               True
# 1999997             0               True
# 1999998             0               True
# 1999999             1               True
#
# [2000000 rows x 10 columns]

# %%
df = df.loc[df['verified_purchase'] != False]
df = df.reset_index(drop=True)
df
# Out:
#          rating                                              title  \
# 0           1.0            Gasoline!! Seriously reeks of gasoline!
# 1           1.0  Useless!  These have massive gaps at pump nozzle.
# 2           5.0                             Hailey loves unicorns!
# 3           1.0                  Not sharp enough to cut smoothly.
# 4           3.0                Pretty, but didn’t close correctly.
# ...         ...                                                ...
# 1681069     5.0                          The only thing I can use!
# 1681070     5.0         Comfortable, good quality, enough to share
# 1681071     5.0                            Best product I’ve found
# 1681072     5.0                        Love Mario Badescu products
# 1681073     5.0                                        Pretty hair
#
#                                                       text  \
# 0        Opened the package & instant migraine. I canno...
# 1        Tops the list for worst purchase. Tried these ...
# 2        Bought this for my granddaughter.  Her entire ...
# 3        These are extremely dull and will wreck your n...
# 4        Mine wouldn’t close correctly so I sent it bac...
# ...                                                    ...
# 1681069  I love this product. It is the only thing I ha...
# 1681070  Great for home pedicures made necessary by Cov...
# 1681071  Love this product. It’s the only hand cream I’...
# 1681072  This is my favorite body wash product.  It doe...
# 1681073  Tried this instead of the same old product I'v...
#
#                                                     images        asin  \
# 0        [{'small_image_url': 'https://images-na.ssl-im...  B00Z03RC80
# 1        [{'small_image_url': 'https://images-na.ssl-im...  B085PRT2MP
# 2                                                       []  B08G81QQ9L
# 3                                                       []  B07YYG76X1
# 4                                                       []  B0761M33BX
# ...                                                    ...         ...
# 1681069                                                 []  B001E96ORO
# 1681070                                                 []  B008E0DBYA
# 1681071                                                 []  B07JL6KGBV
# 1681072                                                 []  B00172F9HO
# 1681073                                                 []  B006OHM5T2
#
#         parent_asin                       user_id      timestamp  \
# 0        B00Z03RC80  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1616743454733
# 1        B085PRT2MP  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1614915977684
# 2        B08G81QQ9L  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1612052493701
# 3        B07YYG76X1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1609700981786
# 4        B07X4FKLNK  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1581313195358
# ...             ...                           ...            ...
# 1681069  B001E96ORO  AEWBUDXP52UZXVWPS5NS7LU4LLPQ  1533327956534
# 1681070  B008E0DBYA  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1594660544449
# 1681071  B07JL6KGBV  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1588879094484
# 1681072  B0BZ1FYHS2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1576425314960
# 1681073  B006OHM5T2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1484085442000
#
#          helpful_vote  verified_purchase
# 0                   0               True
# 1                   0               True
# 2                   0               True
# 3                   0               True
# 4                   0               True
# ...               ...                ...
# 1681069             0               True
# 1681070             0               True
# 1681071             0               True
# 1681072             0               True
# 1681073             1               True
#
# [1681074 rows x 10 columns]

# %%
rating_counts = df['rating'].value_counts()
min_reviews = rating_counts.min()

df = pd.concat([df[df['rating'] == rating].sample(min_reviews) for rating in range(1, 6)])
df = df.sample(frac=1).reset_index(drop=True)

df['rating'].value_counts()
# Out:
# rating
# 5.0    87596
# 3.0    87596
# 4.0    87596
# 1.0    87596
# 2.0    87596
# Name: count, dtype: int64

# %%
df = df[df['rating'].isin([1.0, 5.0])]
df
# Out:
#         rating                                              title  \
# 0          5.0                                         Five Stars
# 6          5.0                          Best purchase of the year
# 9          1.0                                           One Star
# 14         1.0                                Would not recommend
# 15         5.0                   This hair saved me so much time!
# ...        ...                                                ...
# 437964     5.0                                              works
# 437969     1.0  BMC is NOT a great company. Their nail polish ...
# 437972     1.0                                   Leaked Don't Buy
# 437973     5.0                                     Perfect purple
# 437977     5.0                          and is fairly easy to use
#
#                                                      text images        asin  \
# 0       I love this stuff. Won't shave the extra sensi...     []  B00MKD154A
# 6       Amazing results just like professional. I have...     []  B0822PJ8NS
# 9       Yikes. This is not plum. It's pinkish yellow.<...     []  B0047ENSPO
# 14      After less than four months of use, the hair d...     []  B093G3KDMM
# 15      I’m very happy with the passion twists receive...     []  B07XZ621ZG
# ...                                                   ...    ...         ...
# 437964                                        works great     []  B07JP6363M
# 437969  BMC is NOT a great company. Their nail polish ...     []  B00DWKRJ18
# 437972  Product had a  hole in the container cant use ...     []  B0185LCGAC
# 437973  Perfect dark purple. In the light it is very p...     []  B00LIT5TOY
# 437977  It works well, and is fairly easy to use.  I d...     []  B074QTSWWZ
#
#        parent_asin                       user_id      timestamp  helpful_vote  \
# 0       B00MKD154A  AFKENUJ7Q3SNZMNDF4WSL3TO3HWQ  1485925185000             0
# 6       B0CFGCDY2Q  AGS2X6ICFOEZ76ZM3IFX6T3QRZ7Q  1632435234562            24
# 9       B00H8QSHG8  AG4H4WHLCUIJMCIRGXUZWNVIOODA  1456688400000             0
# 14      B081Q6KWT3  AE5JIEXT7UDB5XTHMGLSWBHPH5CQ  1670267453083             1
# 15      B07XZ5M5PJ  AHC6XGKS52LOFRAAWG3F5MM4CXMQ  1596358371610             2
# ...            ...                           ...            ...           ...
# 437964  B071FJFKNZ  AHEP47DOMQAKNTXL626SWB62AVUA  1547763774689             1
# 437969  B00DWKRJ18  AEK446X6NT2HLM4RBLJG45IHKH6A  1424840723000             0
# 437972  B0185LCGAC  AGSMEDEWHRWNKCNRT5HN5E3RUXWA  1504908472406             0
# 437973  B0BJTYJ17Y  AEEK2P4HJ2KXOGEEEXHDPQSEQ3XA  1612682114466             0
# 437977  B074QTSWWZ  AFQWL2K24EAVF7HCN4JOASKLOWCA  1516987485875             4
#
#         verified_purchase
# 0                    True
# 6                    True
# 9                    True
# 14                   True
# 15                   True
# ...                   ...
# 437964               True
# 437969               True
# 437972               True
# 437973               True
# 437977               True
#
# [175192 rows x 10 columns]

# %%
df['rating'].value_counts()
# Out:
# rating
# 5.0    87596
# 1.0    87596
# Name: count, dtype: int64

# %%
(df['title'] + ' ' + df['text']).iloc[0]
# Out:
# "Five Stars I love this stuff. Won't shave the extra sensitive areas with any other product. And it smells great."

# %%
from transformers import TFBertForSequenceClassification, BertTokenizer

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

ratings = df['rating'].tolist()

label_encoder = LabelEncoder()
ratings_encoded = label_encoder.fit_transform(ratings)

X_train, X_test, y_train, y_test = train_test_split((df['title'] + ' ' + df['text']).tolist(), ratings_encoded, test_size=0.2)

# %%
from transformers import AutoTokenizer
import numpy as np

tokenizer = AutoTokenizer.from_pretrained('roberta-base')

train_data = tokenizer(X_train, return_tensors="tf", padding=True, truncation=True, max_length=512)
train_data = dict(train_data)

test_data = tokenizer(X_test, return_tensors="tf", padding=True, truncation=True, max_length=512)
test_data = dict(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
import tensorflow as tf

train_dataset = tf.data.Dataset.from_tensor_slices((
    train_data,
    y_train
)).batch(16)

test_dataset = tf.data.Dataset.from_tensor_slices((
    test_data,
    y_test
)).batch(16)

# %%
from keras import backend

backend.clear_session()

# %%
from transformers import TFAutoModelForSequenceClassification
import numpy as np

model = TFAutoModelForSequenceClassification.from_pretrained('roberta-base', num_labels=len(label_encoder.classes_))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_roberta_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  roberta (TFRobertaMainLaye  multiple                  124055040
#  r)
#
#  classifier (TFRobertaClass  multiple                  592130
#  ificationHead)
#
# =================================================================
# Total params: 124647170 (475.49 MB)
# Trainable params: 124647170 (475.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_dataset,
    epochs=1
)
# Out:
# 8760/8760 [==============================] - 2023s 226ms/step - loss: 0.6941 - accuracy: 0.4985

# %%
evaluation = model.evaluate(test_dataset)
# Out:
# 2190/2190 [==============================] - 185s 83ms/step - loss: 0.6931 - accuracy: 0.5059

# %%
history.history
# Out:
# {'loss': [0.6941114664077759], 'accuracy': [0.49847665429115295]}

# %%
evaluation
# Out:
# [0.6931461691856384, 0.5058649182319641]

# %%
predictions = model.predict(test_dataset)
# Out:
# 2190/2190 [==============================] - 183s 82ms/step

# %%
predicted_labels = np.argmax(predictions.logits, axis=1)
predicted_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import pickle

file_path = '/content/drive/MyDrive/roberta_binary.pkl'

with open(file_path, 'wb') as f:
    pickle.dump({
        'evaluation': evaluation,
        'history': history.history,
        'predicted_labels': predicted_labels,
        'actual_labels': y_test
        }, f)
