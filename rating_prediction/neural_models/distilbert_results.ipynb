# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

file_path = '/content/drive/MyDrive/distilbert_binary.pkl'

with open(file_path, 'rb') as f:
    distil_bin = pickle.load(f)

distil_bin
# Out:
# {'evaluation': [0.6931461691856384, 0.5008419156074524],
#  'history': {'loss': [0.6946852207183838], 'accuracy': [0.4997895061969757]},
#  'predicted_labels': array([1, 1, 1, ..., 1, 1, 1]),
#  'actual_labels': array([0, 0, 1, ..., 0, 0, 1])}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, accuracy_score, f1_score
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(distil_bin['actual_labels'], distil_bin['predicted_labels'])
fig, ax = plt.subplots(figsize=(5, 5))
label_map = {0: "1.0", 1: "5.0"}
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[label_map[i] for i in range(len(label_map))])
cmd.plot(cmap='Blues', ax=ax)

plt.title("DistilBERT Confusion Matrix")
plt.show()

accuracy = accuracy_score(distil_bin['actual_labels'], distil_bin['predicted_labels'])
precision = precision_score(distil_bin['actual_labels'], distil_bin['predicted_labels'], average='micro')
recall = recall_score(distil_bin['actual_labels'], distil_bin['predicted_labels'], average='micro')
f1 = f1_score(distil_bin['actual_labels'], distil_bin['predicted_labels'], average='micro')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.5008419190045378
# Precision: 0.5008419190045378
# Recall: 0.5008419190045378
# F1 Score: 0.5008419190045378

# %%
file_path = '/content/drive/MyDrive/distilbert_tri.pkl'

with open(file_path, 'rb') as f:
    distil_tri = pickle.load(f)

distil_tri
# Out:
# {'evaluation': [1.0986310243606567, 0.3340119421482086],
#  'history': {'loss': [1.1046336889266968], 'accuracy': [0.3331161141395569]},
#  'predicted_labels': array([1, 1, 1, ..., 1, 1, 1]),
#  'actual_labels': array([0, 2, 1, ..., 0, 2, 2])}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, accuracy_score, f1_score
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(distil_tri['actual_labels'], distil_tri['predicted_labels'])
fig, ax = plt.subplots(figsize=(5, 5))
label_map = {0: "1.0", 1: "3.0", 2:"5.0"}
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[label_map[i] for i in range(len(label_map))])
cmd.plot(cmap='Blues', ax=ax)

plt.title("DistilBERT Confusion Matrix")
plt.show()

accuracy = accuracy_score(distil_tri['actual_labels'], distil_tri['predicted_labels'])
precision = precision_score(distil_tri['actual_labels'], distil_tri['predicted_labels'], average='micro')
recall = recall_score(distil_tri['actual_labels'], distil_tri['predicted_labels'], average='micro')
f1 = f1_score(distil_tri['actual_labels'], distil_tri['predicted_labels'], average='micro')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.3340119487042886
# Precision: 0.3340119487042886
# Recall: 0.3340119487042886
# F1 Score: 0.3340119487042886

# %%
file_path = '/content/drive/MyDrive/distilbert_all.pkl'

with open(file_path, 'rb') as f:
    distil_all = pickle.load(f)

distil_all
# Out:
# {'evaluation': [12.893559455871582, 0.2002260386943817],
#  'history': {'loss': [12.895156860351562], 'accuracy': [0.1998436003923416]},
#  'predicted_labels': array([2, 2, 2, ..., 2, 2, 2]),
#  'actual_labels': array([2, 4, 4, ..., 1, 0, 1])}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, accuracy_score, f1_score
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(distil_all['actual_labels'], distil_all['predicted_labels'])
fig, ax = plt.subplots(figsize=(5, 5))
label_map = {0: "1.0", 1: "2.0", 2:"3.0", 3:"4.0", 4:"5.0"}
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[label_map[i] for i in range(len(label_map))])
cmd.plot(cmap='Blues', ax=ax)

plt.title("DistilBERT Confusion Matrix")
plt.show()

accuracy = accuracy_score(distil_all['actual_labels'], distil_all['predicted_labels'])
precision = precision_score(distil_all['actual_labels'], distil_all['predicted_labels'], average='micro')
recall = recall_score(distil_all['actual_labels'], distil_all['predicted_labels'], average='micro')
f1 = f1_score(distil_all['actual_labels'], distil_all['predicted_labels'], average='micro')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.2002260377186173
# Precision: 0.2002260377186173
# Recall: 0.2002260377186173
# F1 Score: 0.2002260377186173
