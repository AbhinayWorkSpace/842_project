# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle

file_path = '/content/drive/MyDrive/distilbert_binary.pkl'

with open(file_path, 'rb') as f:
    distil_bin = pickle.load(f)

distil_bin
# Out:
# {'evaluation': [0.6931461691856384, 0.5008419156074524],
#  'history': {'loss': [0.6946852207183838], 'accuracy': [0.4997895061969757]},
#  'predicted_labels': array([1, 1, 1, ..., 1, 1, 1]),
#  'actual_labels': array([0, 0, 1, ..., 0, 0, 1])}

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(distil_bin['actual_labels'], distil_bin['predicted_labels'])
cm
# Out:
# array([[    0, 17490],
#        [    0, 17549]])

# %%
file_path = '/content/drive/MyDrive/distilbert_tri.pkl'

with open(file_path, 'rb') as f:
    distil_tri = pickle.load(f)

distil_tri
# Out:
# {'evaluation': [1.0986310243606567, 0.3340119421482086],
#  'history': {'loss': [1.1046336889266968], 'accuracy': [0.3331161141395569]},
#  'predicted_labels': array([1, 1, 1, ..., 1, 1, 1]),
#  'actual_labels': array([0, 2, 1, ..., 0, 2, 2])}

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(distil_tri['actual_labels'], distil_tri['predicted_labels'])
cm
# Out:
# array([[    0, 17604,     0],
#        [    0, 17555,     0],
#        [    0, 17399,     0]])

# %%
file_path = '/content/drive/MyDrive/distilbert_all.pkl'

with open(file_path, 'rb') as f:
    distil_all = pickle.load(f)

distil_all
# Out:
# {'evaluation': [12.893559455871582, 0.2002260386943817],
#  'history': {'loss': [12.895156860351562], 'accuracy': [0.1998436003923416]},
#  'predicted_labels': array([2, 2, 2, ..., 2, 2, 2]),
#  'actual_labels': array([2, 4, 4, ..., 1, 0, 1])}

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(distil_all['actual_labels'], distil_all['predicted_labels'])
cm
# Out:
# array([[    0,     0, 17531,     0,     0],
#        [    0,     0, 17572,     0,     0],
#        [    0,     0, 17539,     0,     0],
#        [    0,     0, 17486,     0,     0],
#        [    0,     0, 17468,     0,     0]])
