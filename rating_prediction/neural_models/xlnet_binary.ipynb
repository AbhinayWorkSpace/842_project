# %%
from google.colab import drive

drive.mount('/content/drive')

file_path1 = '/content/drive/My Drive/beauty_personal_care.json'
file_path2 = '/content/drive/My Drive/beauty_personal_care.json'
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd

with open(file_path1, 'r') as file:
    data = [json.loads(line) for line in file]

with open(file_path2, 'r') as file:
    for line in file:
      data.append(json.loads(line))

df = pd.DataFrame(data)
df
# Out:
#          rating                                              title  \
# 0           1.0            Gasoline!! Seriously reeks of gasoline!
# 1           1.0  Useless!  These have massive gaps at pump nozzle.
# 2           5.0                             Hailey loves unicorns!
# 3           1.0                  Not sharp enough to cut smoothly.
# 4           3.0                Pretty, but didn’t close correctly.
# ...         ...                                                ...
# 1999995     5.0                          The only thing I can use!
# 1999996     5.0         Comfortable, good quality, enough to share
# 1999997     5.0                            Best product I’ve found
# 1999998     5.0                        Love Mario Badescu products
# 1999999     5.0                                        Pretty hair
#
#                                                       text  \
# 0        Opened the package & instant migraine. I canno...
# 1        Tops the list for worst purchase. Tried these ...
# 2        Bought this for my granddaughter.  Her entire ...
# 3        These are extremely dull and will wreck your n...
# 4        Mine wouldn’t close correctly so I sent it bac...
# ...                                                    ...
# 1999995  I love this product. It is the only thing I ha...
# 1999996  Great for home pedicures made necessary by Cov...
# 1999997  Love this product. It’s the only hand cream I’...
# 1999998  This is my favorite body wash product.  It doe...
# 1999999  Tried this instead of the same old product I'v...
#
#                                                     images        asin  \
# 0        [{'small_image_url': 'https://images-na.ssl-im...  B00Z03RC80
# 1        [{'small_image_url': 'https://images-na.ssl-im...  B085PRT2MP
# 2                                                       []  B08G81QQ9L
# 3                                                       []  B07YYG76X1
# 4                                                       []  B0761M33BX
# ...                                                    ...         ...
# 1999995                                                 []  B001E96ORO
# 1999996                                                 []  B008E0DBYA
# 1999997                                                 []  B07JL6KGBV
# 1999998                                                 []  B00172F9HO
# 1999999                                                 []  B006OHM5T2
#
#         parent_asin                       user_id      timestamp  \
# 0        B00Z03RC80  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1616743454733
# 1        B085PRT2MP  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1614915977684
# 2        B08G81QQ9L  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1612052493701
# 3        B07YYG76X1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1609700981786
# 4        B07X4FKLNK  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1581313195358
# ...             ...                           ...            ...
# 1999995  B001E96ORO  AEWBUDXP52UZXVWPS5NS7LU4LLPQ  1533327956534
# 1999996  B008E0DBYA  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1594660544449
# 1999997  B07JL6KGBV  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1588879094484
# 1999998  B0BZ1FYHS2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1576425314960
# 1999999  B006OHM5T2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1484085442000
#
#          helpful_vote  verified_purchase
# 0                   0               True
# 1                   0               True
# 2                   0               True
# 3                   0               True
# 4                   0               True
# ...               ...                ...
# 1999995             0               True
# 1999996             0               True
# 1999997             0               True
# 1999998             0               True
# 1999999             1               True
#
# [2000000 rows x 10 columns]

# %%
df = df.loc[df['verified_purchase'] != False]
df = df.reset_index(drop=True)
df
# Out:
#          rating                                              title  \
# 0           1.0            Gasoline!! Seriously reeks of gasoline!
# 1           1.0  Useless!  These have massive gaps at pump nozzle.
# 2           5.0                             Hailey loves unicorns!
# 3           1.0                  Not sharp enough to cut smoothly.
# 4           3.0                Pretty, but didn’t close correctly.
# ...         ...                                                ...
# 1681069     5.0                          The only thing I can use!
# 1681070     5.0         Comfortable, good quality, enough to share
# 1681071     5.0                            Best product I’ve found
# 1681072     5.0                        Love Mario Badescu products
# 1681073     5.0                                        Pretty hair
#
#                                                       text  \
# 0        Opened the package & instant migraine. I canno...
# 1        Tops the list for worst purchase. Tried these ...
# 2        Bought this for my granddaughter.  Her entire ...
# 3        These are extremely dull and will wreck your n...
# 4        Mine wouldn’t close correctly so I sent it bac...
# ...                                                    ...
# 1681069  I love this product. It is the only thing I ha...
# 1681070  Great for home pedicures made necessary by Cov...
# 1681071  Love this product. It’s the only hand cream I’...
# 1681072  This is my favorite body wash product.  It doe...
# 1681073  Tried this instead of the same old product I'v...
#
#                                                     images        asin  \
# 0        [{'small_image_url': 'https://images-na.ssl-im...  B00Z03RC80
# 1        [{'small_image_url': 'https://images-na.ssl-im...  B085PRT2MP
# 2                                                       []  B08G81QQ9L
# 3                                                       []  B07YYG76X1
# 4                                                       []  B0761M33BX
# ...                                                    ...         ...
# 1681069                                                 []  B001E96ORO
# 1681070                                                 []  B008E0DBYA
# 1681071                                                 []  B07JL6KGBV
# 1681072                                                 []  B00172F9HO
# 1681073                                                 []  B006OHM5T2
#
#         parent_asin                       user_id      timestamp  \
# 0        B00Z03RC80  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1616743454733
# 1        B085PRT2MP  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1614915977684
# 2        B08G81QQ9L  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1612052493701
# 3        B07YYG76X1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1609700981786
# 4        B07X4FKLNK  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1581313195358
# ...             ...                           ...            ...
# 1681069  B001E96ORO  AEWBUDXP52UZXVWPS5NS7LU4LLPQ  1533327956534
# 1681070  B008E0DBYA  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1594660544449
# 1681071  B07JL6KGBV  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1588879094484
# 1681072  B0BZ1FYHS2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1576425314960
# 1681073  B006OHM5T2  AFW43SQ2ZDIPEGAX7PSPQC7MSMYQ  1484085442000
#
#          helpful_vote  verified_purchase
# 0                   0               True
# 1                   0               True
# 2                   0               True
# 3                   0               True
# 4                   0               True
# ...               ...                ...
# 1681069             0               True
# 1681070             0               True
# 1681071             0               True
# 1681072             0               True
# 1681073             1               True
#
# [1681074 rows x 10 columns]

# %%
rating_counts = df['rating'].value_counts()
min_reviews = rating_counts.min()

df = pd.concat([df[df['rating'] == rating].sample(min_reviews) for rating in range(1, 6)])
df = df.sample(frac=1).reset_index(drop=True)

df['rating'].value_counts()
# Out:
# rating
# 2.0    87596
# 5.0    87596
# 3.0    87596
# 1.0    87596
# 4.0    87596
# Name: count, dtype: int64

# %%
df = df[df['rating'].isin([1.0, 5.0])]
df
# Out:
#         rating                                              title  \
# 2          5.0                         The best one I ever owned!
# 3          5.0                          Pretty good oil cleanser!
# 4          5.0                                    Very nice brush
# 6          1.0                                 Didn't work for me
# 10         5.0                                               Cute
# ...        ...                                                ...
# 437958     5.0                                          Boots No7
# 437962     5.0                                      Great present
# 437965     1.0                                              Bulky
# 437968     1.0  These were terrible. The clips broke after a m...
# 437972     1.0                                Did not work for me
#
#                                                      text images        asin  \
# 2       I bought mine in November 2019 and it's still ...     []  B07YHJYLFC
# 3       Its great not too watery.<br />My main cleanse...     []  B004OQHZ2M
# 4           Very nice brush. Soft bristles. Fits in hand.     []  B018FYTG70
# 6       Although it is lighted, it is not FOGLESS, unl...     []  B01EG0OD5C
# 10      Great for the holidays.  Soft, I much prefer m...     []  B09KKR7KKR
# ...                                                   ...    ...         ...
# 437958  Love it! Arrived in a timely manner. Love the ...     []  B00PKJXGHK
# 437962                                      Great present     []  B01E6CI9I2
# 437965  They are bulky and look odd on the head no mat...     []  B09B395W9N
# 437968  These were terrible.  The clips broke after a ...     []  B0728LVCMP
# 437972  This turned my gray purple and I’m having a re...     []  B08BW6D5TY
#
#        parent_asin                       user_id      timestamp  helpful_vote  \
# 2       B0C7GH8WRZ  AEUPJUALXRL26OTPRZSYDBO7H7TQ  1636275861115             0
# 3       B004OQHZ2M  AGC2QU55QYRTOGSMXRBO6EHCVMLA  1652241356400             0
# 4       B08SVN83R1  AG7NJNW7ZKNVRMSD57O55YTPQ3YQ  1618004413851             0
# 6       B01EG0OD5C  AF7RVX5AE3DINCU5IQS7SAYDMLFQ  1485053759000             2
# 10      B09KKR7KKR  AER2LDGGKH63NGFYWKR4FCZ2DQYQ  1653842377984             0
# ...            ...                           ...            ...           ...
# 437958  B00PKJXGHK  AG4TTY65I6YUBTQVXE2KNEJGIU7Q  1470403318000             0
# 437962  B01E6CI9HI  AFFWIN7JA24TZORCUTS7LXQAOXMA  1639132606492             0
# 437965  B09D3S6DQ3  AG7J5ZBQCVVWFOSH2DB6JBWXMH6Q  1639402548257             0
# 437968  B0719TNLVJ  AE4O4LCNUC3NGBWILDFM5A6OC2BA  1516924958880             1
# 437972  B08BW6D5TY  AF772JHWQXSA3EUTS2AEROUOCPAA  1675271074759             0
#
#         verified_purchase
# 2                    True
# 3                    True
# 4                    True
# 6                    True
# 10                   True
# ...                   ...
# 437958               True
# 437962               True
# 437965               True
# 437968               True
# 437972               True
#
# [175192 rows x 10 columns]

# %%
df['rating'].value_counts()
# Out:
# rating
# 5.0    87596
# 1.0    87596
# Name: count, dtype: int64

# %%
(df['title'] + ' ' + df['text']).iloc[0]
# Out:
# "The best one I ever owned! I bought mine in November 2019 and it's still going strong! I purchased 2 more to give as gifts for Christmas. The display is a good size, no buttons to accidently push, and the temperature control dial is amazing (and the sound of the dial is satisfying Lol). Quick heat up, fast cool down, easy to handle and lightweight! It doesn't get any more perfect! ❤️"

# %%
from transformers import TFBertForSequenceClassification, BertTokenizer

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

ratings = df['rating'].tolist()

label_encoder = LabelEncoder()
ratings_encoded = label_encoder.fit_transform(ratings)

X_train, X_test, y_train, y_test = train_test_split((df['title'] + ' ' + df['text']).tolist(), ratings_encoded, test_size=0.2)

# %%
from transformers import AutoTokenizer
import numpy as np

tokenizer = AutoTokenizer.from_pretrained('xlnet-base-cased')

train_data = tokenizer(X_train, return_tensors="tf", padding=True, truncation=True, max_length=512)
train_data = dict(train_data)

test_data = tokenizer(X_test, return_tensors="tf", padding=True, truncation=True, max_length=512)
test_data = dict(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]

# %%
import tensorflow as tf

train_dataset = tf.data.Dataset.from_tensor_slices((
    train_data,
    y_train
)).batch(16)

test_dataset = tf.data.Dataset.from_tensor_slices((
    test_data,
    y_test
)).batch(16)

# %%
from keras import backend

backend.clear_session()

# %%
from transformers import TFAutoModelForSequenceClassification
import numpy as np

model = TFAutoModelForSequenceClassification.from_pretrained('xlnet-base-cased', num_labels=len(label_encoder.classes_))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# tf_model.h5:   0%|          | 0.00/565M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/initializers/initializers.py:121: UserWarning: The initializer TruncatedNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Some layers from the model checkpoint at xlnet-base-cased were not used when initializing TFXLNetForSequenceClassification: ['lm_loss']
# - This IS expected if you are initializing TFXLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFXLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFXLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['sequence_summary', 'logits_proj']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tfxl_net_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  transformer (TFXLNetMainLa  multiple                  116718336
#  yer)
#
#  sequence_summary (TFSequen  multiple                  590592
#  ceSummary)
#
#  logits_proj (Dense)         multiple                  1538
#
# =================================================================
# Total params: 117310466 (447.50 MB)
# Trainable params: 117310466 (447.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_dataset,
    epochs=1
)
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_for_sequence_classification/transformer/mask_emb:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_for_sequence_classification/transformer/mask_emb:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_for_sequence_classification/transformer/mask_emb:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_for_sequence_classification/transformer/mask_emb:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 8760/8760 [==============================] - 4425s 500ms/step - loss: 0.6954 - accuracy: 0.4986

# %%
evaluation = model.evaluate(test_dataset)
# Out:
# 2190/2190 [==============================] - 333s 151ms/step - loss: 0.6931 - accuracy: 0.5056

# %%
history.history
# Out:
# {'loss': [0.6953611969947815], 'accuracy': [0.49858370423316956]}

# %%
evaluation
# Out:
# [0.6931461691856384, 0.5055509805679321]

# %%
import pickle

file_path = '/content/drive/MyDrive/xlnet_binary.pkl'

with open(file_path, 'wb') as f:
    pickle.dump({
        'evaluation': evaluation,
        'history': history.history
        }, f)
