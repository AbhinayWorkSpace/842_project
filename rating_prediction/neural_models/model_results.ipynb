# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle

file_path = '/content/drive/MyDrive/roberta_binary.pkl'

with open(file_path, 'rb') as f:
    rob_bin = pickle.load(f)

rob_bin
# Out:
# {'evaluation': [0.6931461691856384, 0.500499427318573],
#  'history': {'loss': [0.6932024359703064], 'accuracy': [0.500217616558075]}}

# %%
file_path = '/content/drive/MyDrive/roberta_tri.pkl'

with open(file_path, 'rb') as f:
    rob_tri = pickle.load(f)

rob_tri
# Out:
# {'evaluation': [1.0986257791519165, 0.3355911672115326],
#  'history': {'loss': [1.0986310243606567], 'accuracy': [0.33276885747909546]}}

# %%
file_path = '/content/drive/MyDrive/roberta_all.pkl'

with open(file_path, 'rb') as f:
    rob_all = pickle.load(f)

rob_all
# Out:
# {'evaluation': [1.6093803644180298, 0.19868487119674683],
#  'history': {'loss': [1.6098170280456543], 'accuracy': [0.1997494250535965]}}
