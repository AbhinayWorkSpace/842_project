# %%
from google.colab import drive

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/cell_phones_accessories.json'
# Out:
# Mounted at /content/drive

# %%
import os

if os.path.exists(file_path):
    print("File exists!")
else:
    print("File does not exist.")
# Out:
# File exists!

# %%
import json
import pandas as pd

with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

df = pd.DataFrame(data)
df
# Out:
#         rating                                              title  \
# 0          4.0                   No white background! It’s clear!
# 1          5.0                Awesome!  Great price!  Works well!
# 2          5.0                 Worked but took an hour to install
# 3          4.0                                             Decent
# 4          5.0                                           LOVE IT!
# ...        ...                                                ...
# 999995     3.0  First of all just an FYI for those wondering y...
# 999996     5.0                              Very good protection.
# 999997     5.0                                 Good charging cord
# 999998     5.0                     Perfect for iPhone! Love this!
# 999999     5.0                                 Super Easy Upgrade
#
#                                                      text  \
# 0       I bought this bc I thought it had the nice whi...
# ...

# %%
rating_counts1 = df['rating'].value_counts()
rating_counts1
# Out:
# rating
# 5.0    632499
# 4.0    130049
# 1.0    101242
# 3.0     80024
# 2.0     56186
# Name: count, dtype: int64

# %%
df = df.loc[df['verified_purchase'] != False]
df = df.reset_index(drop=True)

# %%
rating_counts2 = df['rating'].value_counts()
rating_counts2
# Out:
# rating
# 5.0    596480
# 4.0    118699
# 1.0     95077
# 3.0     74666
# 2.0     52754
# Name: count, dtype: int64

# %%
rating_counts1 - rating_counts2
# Out:
# rating
# 5.0    36019
# 4.0    11350
# 1.0     6165
# 3.0     5358
# 2.0     3432
# Name: count, dtype: int64

# %%
(1000000 - len(df))/1000000
# Out:
# 0.062324

# %%
(rating_counts1 - rating_counts2)[5]/sum(rating_counts1 - rating_counts2)
# Out:
# 0.5779314549772159
